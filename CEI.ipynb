# %%
# !pip install "camelot-py[cv]"
# !apt install python3-tk ghostscript
# Out:
# ...
#      |████████████████████████████████| 40 kB 8.4 kB/s
# ...
#      |████████████████████████████████| 5.6 MB 5.9 MB/s
# ...
#      |████████████████████████████████| 77 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 11.7 MB 155 kB/s
# ...
#      |████████████████████████████████| 3.2 MB 38.2 MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61101 sha256=c1f95411e87d6c5cad7c61828f3f2c6bea541e36298b33a706f6009b70b38c90
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-tk is already the newest version (3.6.9-1~18.04).
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono gsfonts libcupsfilters1 libcupsimage2
#   libgs9 libgs9-common libijs-0.35 libjbig2dec0 poppler-data
# Suggested packages:
# ...

# %%
import camelot
tables = camelot.read_pdf('file.pdf')
#Pages 41-72
tables
# Out:
# <TableList n=0>

# %%
# !pip install --force-reinstall tabula-py
# Out:
# ...
#   Using cached tabula_py-2.2.0-py3-none-any.whl (11.7 MB)
# ...
#   Using cached pandas-1.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
# ...
#   Using cached distro-1.6.0-py2.py3-none-any.whl (19 kB)
# ...
#   Using cached numpy-1.21.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# ...
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# ...
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.1
#     Uninstalling pytz-2021.1:
#       Successfully uninstalled pytz-2021.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
# ...

# %%
import tabula
import os

# %%
import numpy as np

# %%
tables = tabula.read_pdf("file.pdf", pages="41-72")
print(tables)
tabula.convert_into("file.pdf", "equalityindex.csv", output_format="csv", pages='41-72')
# Out:
# [                               Unnamed: 0  ... Unnamed: 5
# 0                                  3M Co.  ...        NaN
# 1                     A|X Armani Exchange  ...        NaN
# 2                                ABB Inc.  ...        NaN
# 3                     Abbott Laboratories  ...      103.0
# 4                             AbbVie Inc.  ...       96.0
# 5                 Abercrombie & Fitch Co.  ...      675.0
# 6                     ABM Industries Inc.  ...      463.0
# 7                               Accenture  ...        NaN
# 8                     Activision Blizzard  ...      405.0
# 9    Adaptive Biotechnologies Corporation  ...        NaN
# 10              Adidas North America Inc.  ...        NaN
# 11                             Adobe Inc.  ...      339.0
# 12                                    ADP  ...      239.0
# 13   Advance Auto Parts (Advance Holding)  ...      326.0
# 14            Advanced Micro Devices Inc.  ...      460.0
# ...
